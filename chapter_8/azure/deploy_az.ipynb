# %%
from azure.ai.ml import MLClient
from azure.ai.ml.entities import (
    ManagedOnlineEndpoint,
    ManagedOnlineDeployment,
    Model,
    Environment,
    CodeConfiguration,
)
registry_name = "HuggingFace"
model_name = "mstaron/declBERTa"
model_id = f"azureml://registries/HuggingFace/models/mstaron/declBERTa/labels/latest"

# %%
from azure.identity import DefaultAzureCredential
from azure.ai.ml import MLClient

# Get credential object from Azure CLI
credential = DefaultAzureCredential()

# Get a handle to the workspace
ml_client = MLClient(
    credential=credential,
    subscription_id="1cb58e77-690a-4d23-84fc-792badb52ffa",
    resource_group_name="MyResourceGroup",
    workspace_name="EngineeringGenerativeAI"
)
# Out:
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented

# %%
import time
endpoint_name="hf-ep-" + str(int(time.time())) # endpoint name must be unique per Azure region, hence appending timestamp 
ml_client.begin_create_or_update(ManagedOnlineEndpoint(name=endpoint_name) ).wait()
ml_client.online_deployments.begin_create_or_update(ManagedOnlineDeployment(
    name="demo",
    endpoint_name=endpoint_name,
    model=model_id,
    instance_type="Standard_DS3_v2",
    instance_count=1,
)).wait()
endpoint = ml_client.online_endpoints.get(endpoint_name)
endpoint.traffic = {"demo": 100}
ml_client.begin_create_or_update(endpoint).result()
# Out:
# Check: endpoint hf-ep-1748337874 exists
# ---------------------------------------------------------------------------
# HttpResponseError                         Traceback (most recent call last)
# Cell In[18], line 4
#       2 endpoint_name="hf-ep-" + str(int(time.time())) # endpoint name must be unique per Azure region, hence appending timestamp
#       3 ml_client.begin_create_or_update(ManagedOnlineEndpoint(name=endpoint_name) ).wait()
# ----> 4 ml_client.online_deployments.begin_create_or_update(ManagedOnlineDeployment(
#       5     name="demo",
#       6     endpoint_name=endpoint_name,
#       7     model=model_id,
#       8     instance_type="Standard_DS3_v2",
#       9     instance_count=1,
#      10 )).wait()
#      11 endpoint = ml_client.online_endpoints.get(endpoint_name)
#      12 endpoint.traffic = {"demo": 100}
#
# ...

# %%
import json
scoring_file = "./scFile.json"

endpoint_name = "declBERTa-endpoint"

response = ml_client.online_endpoints.invoke(
    endpoint_name=endpoint_name,
    deployment_name="demo",
    request_file=scoring_file,
)
response_json = json.loads(response)
print(json.dumps(response_json, indent=2))
# Out:
# ---------------------------------------------------------------------------
# ResourceNotFoundError                     Traceback (most recent call last)
# Cell In[19], line 6
#       2 scoring_file = "./scFile.json"
#       4 engpoint_name = "declBERTa-endpoint"
# ----> 6 response = ml_client.online_endpoints.invoke(
#       7     endpoint_name=endpoint_name,
#       8     deployment_name="demo",
#       9     request_file=scoring_file,
#      10 )
#      11 response_json = json.loads(response)
#      12 print(json.dumps(response_json, indent=2))
#
# File ~/.local/lib/python3.12/site-packages/azure/core/tracing/decorator.py:116, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     114 for key, value in func_tracing_attributes.items():
#     115     span.add_attribute(key, value)
# --> 116 return func(*args, **kwargs)
#
# ...
